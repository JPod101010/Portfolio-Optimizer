# %% [markdown]
# ### Markowitz portfolio optimizing strategy

# %% [markdown]
# ### Load, enrich and save the csv files

# %%
from src.portfolioOptimizer.PortfolioOptimizer import PortfolioOptimizer

_po = PortfolioOptimizer(
    [
        'AAPL',
        'GOOGL',
        'TSLA',
        'PLTR',
        'NVDA'
    ]
)
_po.download_data()
_po.enrich_data()
_po.save_data()

# %% [markdown]
# ### Visualize all the plots with changes

# %%
from src.visualizers.Visualizer import Visualizer

TO_VISUALIZE = ['Close', 'RawChange', 'LogChange']

for ticker, dataframe in _po._data.items():
    Visualizer.visualize(
        df=dataframe,
        values_to_visualize=TO_VISUALIZE,
        ticker=ticker,
        show_mean=True,
        show_stddev=True
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 TO_VISUALIZE = ['Close', 'RawChange', 'LogChange']
#       5 for ticker, dataframe in _po._data.items():
# ----> 6     Visualizer.visualize(
#       7         df=dataframe,
#       8         values_to_visualize=TO_VISUALIZE,
#       9         ticker=ticker,
#      10         show_mean=True,
#      11         show_stddev=True
#      12     )
#
# File ~/PORTFOLIO/The-Analysis-Of-Time-Series/src/visualizers/Visualizer.py:59, in Visualizer.visualize(df, values_to_visualize, ticker, show_mean, show_stddev, print_analysis, show_grid)
#      56     axes[j].axis('off')
#      58 plt.tight_layout()
# ---> 59 plt.show()
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File ~/.local/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py:2157, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2157         self.figure.draw(renderer)
#    2158 if bbox_inches:
#    2159     if bbox_inches == "tight":
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py:1408, in Axis.draw(self, renderer)
#    1405 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1407 for tick in ticks_to_draw:
# -> 1408     tick.draw(renderer)
#    1410 # Shift label away from axes to avoid overlapping ticklabels.
#    1411 self._update_label_position(renderer)
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py:276, in Tick.draw(self, renderer)
#     273 renderer.open_group(self.__name__, gid=self.get_gid())
#     274 for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                self.label1, self.label2]:
# --> 276     artist.draw(renderer)
#     277 renderer.close_group(self.__name__)
#     278 self.stale = False
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/text.py:778, in Text.draw(self, renderer)
#     775     self.update_bbox_position_size(renderer)
#     776     self._bbox_patch.draw(renderer)
# --> 778 gc = renderer.new_gc()
#     779 gc.set_foreground(self.get_color())
#     780 gc.set_alpha(self.get_alpha())
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py:606, in RendererBase.new_gc(self)
#     604 def new_gc(self):
#     605     """Return an instance of a `.GraphicsContextBase`."""
# --> 606     return GraphicsContextBase()
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py:693, in GraphicsContextBase.__init__(self)
#     691 self._rgb = (0.0, 0.0, 0.0, 1.0)
#     692 self._hatch = None
# --> 693 self._hatch_color = colors.to_rgba(rcParams['hatch.color'])
#     694 self._hatch_linewidth = rcParams['hatch.linewidth']
#     695 self._url = None
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:308, in to_rgba(c, alpha)
#     306         c = c[0]
#     307 # Special-case nth color syntax because it should not be cached.
# --> 308 if _is_nth_color(c):
#     309     prop_cycler = mpl.rcParams['axes.prop_cycle']
#     310     colors = prop_cycler.by_key().get('color', ['k'])
#
# File /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:221, in _is_nth_color(c)
#     219 def _is_nth_color(c):
#     220     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 221     return isinstance(c, str) and _nth_color_re.match(c)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Distribution visualization

# %%
MAX_BINS = 50

for ticker, dataframe in _po._data.items():
    Visualizer.visualize_distribution(
        df=dataframe,
        values_to_visualize=TO_VISUALIZE,
        ticker=ticker,
        bins=MAX_BINS
    )

# %% [markdown]
# ### Optimize the portfolio
# - Construct the covariance matrix
# - Construct the system of linear equations with weight vector
# - Compute the best weights according to the preffered choice

# %%
_po = PortfolioOptimizer(
    [
    "AAPL","MSFT","GOOGL","GOOG","AMZN","NVDA","BRK.B","JNJ","META","TSLA",
    "UNH","XOM","JPM","V","PG","MA","CVX","HD","BAC","KO","PFE","MRK","WMT","LLY",
    "VZ","ABBV","PEP","CSCO","MCD","ADBE","AVGO","T","COST","CMCSA","ACN","TMUS",
    "ABT","CRM","TMO","INTC","ORCL","QCOM","AMD","NKE","TXN","NEE","PM","DHR","LIN",
    "LLR","HON","UPS","SCHW","LOW","RTX","AMGN","UNP","MS","QGEN","AXP","SBUX","MMM",
    "GILD","BKNG","BLK","C","MSCI","MDT","CAT","BMY","AMT","ZTS","SPGI","FIS","CVS",
    "NOW","ADP","PLTR","DE","SYK","LMT","GE","INTU","MDLZ","CHTR","DUK","MO","BDX",
    "TGT","CCI","PNC","CCI","CL","GM","USB","ELV","AMAT","MMC","CCI","MCO","APD",
    "WM","KMB","MMC","CME","DUK","TJX","SO","D","CI","LHX","COF","ICE","CCI","BSX",
    "GM","MET","SHW","CB","PLD","F","TRV","TFC","AON","EOG","TEL","PGR","AEP","BIIB",
    "BK","AXP","COG","EXC","ADM","CLX","KHC","ISRG","PSA","NOC","MRNA","ICE","EL",
    "PNC","AIG","GIS","MAR","KMB","HLT","PSX","DD","BLK","CF","TROW","AFL","ADI","EW",
    "ADSK","RF","HUM","SPG","DXC","DOW","WM","SO","EQR","ZBRA","ECL","DHI","IFF",
    "AJG","AVY","APH","KR","GLW","CNP","CHD","CF","XEL","STE","NEM","PNR","PRU",
    "GIS","HPQ","ROP","WY","FTNT","ETN","JKHY","VLO","PSA","DRI","MNST","UAL","ODFL",
    "HCA","PKI","ROST","MLM","MSI","ADM","WELL","BBY","PEAK","TGT","RSG","RJF","PXD",
    "ABMD","DTE","HP","ATVI","LEN","EXPE","EXR","DRE","UAL","KIM","SLB","APTV","HSY",
    "AEE","TEL","XEL","STZ","KSS","ETR","CERN","LB","AOS","KMX","BF.B","BBWI","RL",
    "HBAN","ALLE","CMS","KMI","UA","HES","FBHS","MLR","NTRS","NWL","VNO","HWM","CFX","LH",
    "AZO","VFC","HIG","VMC","SYF","GWW","AAL","LUV","MLP","NUE","WRK","ALLE","A","INFO",
    "KEY","IFF","PNW","PKG","ZBH","UA","PNW","ALLE","PNC","MTB","HSY","VTR","FISV","ZBRA",
    "LNT","CINF","PNR","PNW","DHI","POOL","NDSN","NWSA","NWS","ROL","EQT","WEC","PNC",
    "PNW","SWKS","DG","BEN","HII","NDAQ","GL","VRTX","URI","LKQ","SIVB","XLNX","APA","BKR"
],
dir_name='sp500'
)

_po.download_data()
_po.enrich_data()
_po.save_data()
# Out:
# 1 Failed download:
# ['BRK.B']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping BRK.B: no data returned
# 1 Failed download:
# ['LLR']: YFPricesMissingError('possibly delisted; no price data found  (period=5y)')
# [WARN] Skipping LLR: no data returned
# 1 Failed download:
# ['COG']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping COG: no data returned
# 1 Failed download:
# ['PKI']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping PKI: no data returned
# 1 Failed download:
# ['PEAK']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping PEAK: no data returned
# 1 Failed download:
# ['PXD']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping PXD: no data returned
# 1 Failed download:
# ['ABMD']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping ABMD: no data returned
# 1 Failed download:
# ['ATVI']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping ATVI: no data returned
# 1 Failed download:
# ['DRE']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping DRE: no data returned
# 1 Failed download:
# ['CERN']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping CERN: no data returned
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (period=5y)')
# [WARN] Skipping BF.B: no data returned
# 1 Failed download:
# ['HES']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping HES: no data returned
# 1 Failed download:
# ['FBHS']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping FBHS: no data returned
# 1 Failed download:
# ['CFX']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping CFX: no data returned
# 1 Failed download:
# ['WRK']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping WRK: no data returned
# 1 Failed download:
# ['SIVB']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping SIVB: no data returned
# 1 Failed download:
# ['XLNX']: YFPricesMissingError('possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")')
# [WARN] Skipping XLNX: no data returned

# %%
res = _po.optimize(
    method='sharpe',
)

_po.interpret_result(
    result=res,
    timeframe='annually'
)
# Out:
# ['AAPL', 'MSFT', 'GOOGL', 'GOOG', 'AMZN', 'NVDA', 'BRK.B', 'JNJ', 'META', 'TSLA', 'UNH', 'XOM', 'JPM', 'V', 'PG', 'MA', 'CVX', 'HD', 'BAC', 'KO', 'PFE', 'MRK', 'WMT', 'LLY', 'VZ', 'ABBV', 'PEP', 'CSCO', 'MCD', 'ADBE', 'AVGO', 'T', 'COST', 'CMCSA', 'ACN', 'TMUS', 'ABT', 'CRM', 'TMO', 'INTC', 'ORCL', 'QCOM', 'AMD', 'NKE', 'TXN', 'NEE', 'PM', 'DHR', 'LIN', 'LLR', 'HON', 'UPS', 'SCHW', 'LOW', 'RTX', 'AMGN', 'UNP', 'MS', 'QGEN', 'AXP', 'SBUX', 'MMM', 'GILD', 'BKNG', 'BLK', 'C', 'MSCI', 'MDT', 'CAT', 'BMY', 'AMT', 'ZTS', 'SPGI', 'FIS', 'CVS', 'NOW', 'ADP', 'PLTR', 'DE', 'SYK', 'LMT', 'GE', 'INTU', 'MDLZ', 'CHTR', 'DUK', 'MO', 'BDX', 'TGT', 'CCI', 'PNC', 'CCI', 'CL', 'GM', 'USB', 'ELV', 'AMAT', 'MMC', 'CCI', 'MCO', 'APD', 'WM', 'KMB', 'MMC', 'CME', 'DUK', 'TJX', 'SO', 'D', 'CI', 'LHX', 'COF', 'ICE', 'CCI', 'BSX', 'GM', 'MET', 'SHW', 'CB', 'PLD', 'F', 'TRV', 'TFC', 'AON', 'EOG', 'TEL', 'PGR', 'AEP', 'BIIB', 'BK', 'AXP', 'COG', 'EXC', 'ADM', 'CLX', 'KHC', 'ISRG', 'PSA', 'NOC', 'MRNA', 'ICE', 'EL', 'PNC', 'AIG', 'GIS', 'MAR', 'KMB', 'HLT', 'PSX', 'DD', 'BLK', 'CF', 'TROW', 'AFL', 'ADI', 'EW', 'ADSK', 'RF', 'HUM', 'SPG', 'DXC', 'DOW', 'WM', 'SO', 'EQR', 'ZBRA', 'ECL', 'DHI', 'IFF', 'AJG', 'AVY', 'APH', 'KR', 'GLW', 'CNP', 'CHD', 'CF', 'XEL', 'STE', 'NEM', 'PNR', 'PRU', 'GIS', 'HPQ', 'ROP', 'WY', 'FTNT', 'ETN', 'JKHY', 'VLO', 'PSA', 'DRI', 'MNST', 'UAL', 'ODFL', 'HCA', 'PKI', 'ROST', 'MLM', 'MSI', 'ADM', 'WELL', 'BBY', 'PEAK', 'TGT', 'RSG', 'RJF', 'PXD', 'ABMD', 'DTE', 'HP', 'ATVI', 'LEN', 'EXPE', 'EXR', 'DRE', 'UAL', 'KIM', 'SLB', 'APTV', 'HSY', 'AEE', 'TEL', 'XEL', 'STZ', 'KSS', 'ETR', 'CERN', 'LB', 'AOS', 'KMX', 'BF.B', 'BBWI', 'RL', 'HBAN', 'ALLE', 'CMS', 'KMI', 'UA', 'HES', 'FBHS', 'MLR', 'NTRS', 'NWL', 'VNO', 'HWM', 'CFX', 'LH', 'AZO', 'VFC', 'HIG', 'VMC', 'SYF', 'GWW', 'AAL', 'LUV', 'MLP', 'NUE', 'WRK', 'ALLE', 'A', 'INFO', 'KEY', 'IFF', 'PNW', 'PKG', 'ZBH', 'UA', 'PNW', 'ALLE', 'PNC', 'MTB', 'HSY', 'VTR', 'FISV', 'ZBRA', 'LNT', 'CINF', 'PNR', 'PNW', 'DHI', 'POOL', 'NDSN', 'NWSA', 'NWS', 'ROL', 'EQT', 'WEC', 'PNC', 'PNW', 'SWKS', 'DG', 'BEN', 'HII', 'NDAQ', 'GL', 'VRTX', 'URI', 'LKQ', 'SIVB', 'XLNX', 'APA', 'BKR']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 30
#       1 _po = PortfolioOptimizer(
#       2     [
#       3     "AAPL","MSFT","GOOGL","GOOG","AMZN","NVDA","BRK.B","JNJ","META","TSLA",
#    (...)
#      27 dir_name='sp500'
#      28 )
# ---> 30 res = _po.optimize(
#      31     method='sharpe',
#      32 )
#      34 _po.interpret_result(
#      35     result=res,
#      36     timeframe='annually'
#      37 )
#
# File ~/PORTFOLIO/The-Analysis-Of-Time-Series/src/portfolioOptimizer/PortfolioOptimizer.py:172, in PortfolioOptimizer.optimize(self, method, target, bounds, allow_short)
#     169 else:
#     170     raise NotImplementedError(f"Optimization method {method} is not implemented.")
# --> 172 res = minimize(
#     173     objective,
#     174     init_guess,
#     175     method='SLSQP',
#     176     bounds=bounds,
#     177     constraints=constraints
#     178 )
#     180 optimal_weights = res.x
#     181 port_return, port_vol, sharpe_ratio = self._portfolio_metrics(optimal_weights)
#
# File /usr/local/lib/python3.11/dist-packages/scipy/optimize/_minimize.py:796, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     793     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     794                            **options)
#     795 elif meth == 'slsqp':
# --> 796     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     797                           constraints, callback=callback, **options)
#     798 elif meth == 'trust-constr':
#     799     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     800                                        bounds, constraints,
#     801                                        callback=callback, **options)
#
# File /usr/local/lib/python3.11/dist-packages/scipy/optimize/_slsqp_py.py:419, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, workers, **unknown_options)
#     416     xu[infbnd[:, 1]] = np.nan
#     418 # ScalarFunction provides function and gradient evaluation
# --> 419 sf = _prepare_scalar_function(func, x, jac=jac, args=args, epsilon=eps,
#     420                               finite_diff_rel_step=finite_diff_rel_step,
#     421                               bounds=new_bounds, workers=workers)
#     422 # gh11403 SLSQP sometimes exceeds bounds by 1 or 2 ULP, make sure this
#     423 # doesn't get sent to the func/grad evaluator.
#     424 wrapped_fun = _clip_x_for_func(sf.fun, new_bounds)
#
# File /usr/local/lib/python3.11/dist-packages/scipy/optimize/_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:274, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     272 # Initial function evaluation
#     273 self._nfev = 0
# --> 274 self._update_fun()
#     276 # Initial gradient evaluation
#     277 self._wrapped_grad = _ScalarGradWrapper(
#     278     grad,
#     279     fun=self._wrapped_fun,
#     280     args=args,
#     281     finite_diff_options=finite_diff_options,
#     282 )
#
# File /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File /usr/local/lib/python3.11/dist-packages/scipy/_lib/_util.py:590, in _ScalarFunctionWrapper.__call__(self, x)
#     587 def __call__(self, x):
#     588     # Send a copy because the user may overwrite it.
#     589     # The user of this class might want `x` to remain unchanged.
# --> 590     fx = self.f(np.copy(x), *self.args)
#     591     self.nfev += 1
#     593     # Make sure the function returns a true scalar
#
# File ~/PORTFOLIO/The-Analysis-Of-Time-Series/src/portfolioOptimizer/PortfolioOptimizer.py:109, in PortfolioOptimizer._objective_neg_sharpe(self, weights)
#     107 def _objective_neg_sharpe(self, weights: np.ndarray):
#     108     """Objective function for maximizing Sharpe: minimize negative Sharpe."""
# --> 109     _, _, sharpe = self._portfolio_metrics(weights)
#     110     return -sharpe
#
# File ~/PORTFOLIO/The-Analysis-Of-Time-Series/src/portfolioOptimizer/PortfolioOptimizer.py:102, in PortfolioOptimizer._portfolio_metrics(self, weights)
#     100 def _portfolio_metrics(self, weights: np.ndarray):
#     101     """Compute portfolio return, volatility, and Sharpe ratio."""
# --> 102     port_return = np.dot(weights, self._mean_returns)
#     103     port_vol = np.sqrt(weights.T @ self._cov_matrix.values @ weights)
#     104     sharpe_ratio = port_return / port_vol if port_vol != 0 else 0
#
# ValueError: shapes (303,) and (0,) not aligned: 303 (dim 0) != 0 (dim 0)
